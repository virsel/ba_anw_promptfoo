# %%
from utils import *
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print_analysis("v1_deepseekchat.json")
# Out:
# acc: 0.9285714285714286
#                precision    recall  f1-score   support
#
#      code_bug       0.78      1.00      0.88        14
#     cpu_usage       1.00      0.92      0.96        26
# network_delay       1.00      0.88      0.93        16
#
#      accuracy                           0.93        56
#     macro avg       0.93      0.93      0.92        56
#  weighted avg       0.94      0.93      0.93        56

# %%
print_analysis("v1_gpt4o.json")
# Out:
# acc: 0.9464285714285714
#                precision    recall  f1-score   support
#
#      code_bug       0.87      0.93      0.90        14
#     cpu_usage       0.96      1.00      0.98        26
# network_delay       1.00      0.88      0.93        16
#
#      accuracy                           0.95        56
#     macro avg       0.94      0.93      0.94        56
#  weighted avg       0.95      0.95      0.95        56
