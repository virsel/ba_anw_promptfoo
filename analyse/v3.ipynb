# %%
from utils import *
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print_analysis("v3_deepseekchat.json")
# Out:
# acc: 0.9642857142857143
#                precision    recall  f1-score   support
#
#      code_bug       0.88      1.00      0.93        14
#     cpu_usage       1.00      1.00      1.00        26
# network_delay       1.00      0.88      0.93        16
#
#      accuracy                           0.96        56
#     macro avg       0.96      0.96      0.96        56
#  weighted avg       0.97      0.96      0.96        56

# %%
print_analysis("v3_gpt4o.json")
# Out:
# acc: 1.0
#                precision    recall  f1-score   support
#
#      code_bug       1.00      1.00      1.00        14
#     cpu_usage       1.00      1.00      1.00        26
# network_delay       1.00      1.00      1.00        16
#
#      accuracy                           1.00        56
#     macro avg       1.00      1.00      1.00        56
#  weighted avg       1.00      1.00      1.00        56
